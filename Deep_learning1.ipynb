# %% [markdown]
# <a href="https://colab.research.google.com/github/Saketbishnu/AI-ML-Journey/blob/main/Deep_learning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#implementation of neural networks
import torch
import torch.nn as nn

# %%
#input
#to get exact output we can use {torch.manual_seed(42)}
inputs = torch.tensor([1.0, 2.0, 3.0])

# %%
neuron = nn.Linear(in_features=3, out_features=1)

# %%
output = neuron(inputs)

# %%
output
# Out:
# tensor([0.8998], grad_fn=<ViewBackward0>)

# %%
#verify formula
neuron.weight @ inputs
# Out:
# tensor([0.3624], grad_fn=<MvBackward0>)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[-0.3339, -0.3990,  0.4981]], requires_grad=True)

# %%
neuron.bias
# Out:
# Parameter containing:
# tensor([0.5375], requires_grad=True)
